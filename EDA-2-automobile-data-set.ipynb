# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# *Exploratory Data Analysis (EDA) is used on the one hand to answer questions, test business assumptions, generate hypotheses for further analysis.we can get good knowledge about the data.
# *It is the most important and first step in the machinelearning part.

# %%
# importing the library for EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the data set from the location

# %%
ds=pd.read_csv('automobile.csv')

# %%
#checking the first and last value of the dataset

# %%
ds.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
ds.tail()
# Out:
#      symboling  normalized-losses   make aspiration num-of-doors body-style  \
# 196         -1                 95  volvo        std         four      sedan
# 197         -1                 95  volvo      turbo         four      sedan
# 198         -1                 95  volvo        std         four      sedan
# 199         -1                 95  volvo      turbo         four      sedan
# 200         -1                 95  volvo      turbo         four      sedan
#
#     drive-wheels engine-location  wheel-base    length  ...  \
# 196          rwd           front       109.1  0.907256  ...
# 197          rwd           front       109.1  0.907256  ...
# 198          rwd           front       109.1  0.907256  ...
# 199          rwd           front       109.1  0.907256  ...
# 200          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
#getting the mathmatical insights of the data

# %%
ds.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
#checking fpr the null value

# %%
#null value should be handled properly because the null value provides improper insights 
#the null value can be handled either by droping the data set else by imputing the value by doing calculation based on the
importance of the data

# %%
ds.isnull()
# Out:
#      symboling  normalized-losses   make  aspiration  num-of-doors  \
# 0        False              False  False       False         False
# 1        False              False  False       False         False
# 2        False              False  False       False         False
# 3        False              False  False       False         False
# 4        False              False  False       False         False
# ..         ...                ...    ...         ...           ...
# 196      False              False  False       False         False
# 197      False              False  False       False         False
# 198      False              False  False       False         False
# 199      False              False  False       False         False
# 200      False              False  False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  length  ...  \
# 0         False         False            False       False   False  ...
# ...

# %%
visualization of the null value using heatmap will give better understanding about the null value and the column or row associated with it

# %%
sns.heatmap(ds.isnull(),yticklabels=False,cmap='viridis')

# %%
#scatter plot checking relationship between horsepower and the price
#checking the relationship between the horsepower and peak Rpm

#sns.scatter(ds['horsepower'],ds['peak-rpm'])
sns.scatterplot(data=ds, x="peak-rpm", y="horsepower")

# %%
correlation

# %%
getting some insight about correlation using seaborn and matplotlib

# %%
correlation helps us to find the relation ship between two categories

# %%
using fig size because it  will not provide the insights(Automatically ) clearly we have to mannually specify the size of the confusion matrix table

# %%
comat=ds.corr()
fig= plt.subplots(figsize=(15,15))
size=sns.heatmap(comat,annot=True, linewidths=0)
bottom,top=size.get_ylim()
size.set_ylim(bottom+0.5,top-0.5)
# Out:
# (19.0, 0.0)

# %%
finding the relationship between the enginesize-horsepower,peakrpm-price,enginesize-peakrpm using the scatterplot

# %%
sns.scatterplot(data=ds, x="engine-size", y="horsepower")

# %%
sns.scatterplot(data=ds, x="engine-size", y="peak-rpm")

# %%
sns.scatterplot(data=ds, x="peak-rpm", y="price")

# %%
grouping the make and price and adding the price value according to the make

# %%
ds[['make', 'price']].groupby(['make']).sum()
# Out:
#                   price
# make
# alfa-romero     46495.0
# audi           107155.0
# bmw            208950.0
# chevrolet       18021.0
# dodge           70879.0
# honda          106401.0
# isuzu           17833.0
# jaguar         103800.0
# mazda          181099.0
# mercedes-benz  269176.0
# mercury         16503.0
# mitsubishi     120117.0
# nissan         187482.0
# peugot         170380.0
# plymouth        55744.0
# porsche        125602.0
# renault         19190.0
# saab            91340.0
# subaru         102495.0
# toyota         316346.0
# volkswagen     120930.0
# volvo          198695.0

# %%
print(ds[['make', 'price']])
# Out:
#             make    price
# 0    alfa-romero  13495.0
# 1    alfa-romero  16500.0
# 2    alfa-romero  16500.0
# 3           audi  13950.0
# 4           audi  17450.0
# ..           ...      ...
# 196        volvo  16845.0
# 197        volvo  19045.0
# 198        volvo  21485.0
# 199        volvo  22470.0
# 200        volvo  22625.0
#
# [201 rows x 2 columns]

# %%
ds[['make', 'price']]
# Out:
#             make    price
# 0    alfa-romero  13495.0
# 1    alfa-romero  16500.0
# 2    alfa-romero  16500.0
# 3           audi  13950.0
# 4           audi  17450.0
# ..           ...      ...
# 196        volvo  16845.0
# 197        volvo  19045.0
# 198        volvo  21485.0
# 199        volvo  22470.0
# 200        volvo  22625.0
#
# [201 rows x 2 columns]
